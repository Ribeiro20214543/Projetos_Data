# %%
import pandas as pd
import pandera as pa

# %%
data = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
data = data.drop(['codigo_ocorrencia1', 'codigo_ocorrencia3','codigo_ocorrencia4', 'ocorrencia_latitude', 'ocorrencia_longitude', 
          'ocorrencia_pais', 'investigacao_aeronave_liberada','investigacao_status', 'divulgacao_relatorio_numero',
          'divulgacao_relatorio_publicado', 'divulgacao_dia_publicacao','total_aeronaves_envolvidas', 
          'ocorrencia_saida_pista'], axis=1)
data.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0
# 4        16:30:00                    0

# %%
data.replace(['**','###!','####','****','*****','NULL'], pd.NA, inplace=True)

# %%
data
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 2               VIAMÃO            RS                 <NA>     2012-01-06
# 3        SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4             SÃO SEPÉ            RS                 <NA>     2012-01-06
# ...                ...           ...                  ...            ...
# 5162             JATAÍ            GO                 <NA>     2021-12-30
# 5163           MARACAÍ            SP                 <NA>     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 1           13:44:00                    3
# 2           13:00:00                    0
# 3           17:00:00                    0
# 4           16:30:00                    0
# ...              ...                  ...
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0
#
# [5167 rows x 9 columns]

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        "ocorrencia_aerodromo": pa.Column(pa.String, nullable=True),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int)   
    }
)

# %%
schema.validate(data)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 2               VIAMÃO            RS                 <NA>     2012-01-06
# 3        SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4             SÃO SEPÉ            RS                 <NA>     2012-01-06
# ...                ...           ...                  ...            ...
# 5162             JATAÍ            GO                 <NA>     2021-12-30
# 5163           MARACAÍ            SP                 <NA>     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 1           13:44:00                    3
# 2           13:00:00                    0
# 3           17:00:00                    0
# 4           16:30:00                    0
# ...              ...                  ...
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0
#
# [5167 rows x 9 columns]

# %%
data.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
data.loc[1]
# Out:
# codigo_ocorrencia                         45331
# codigo_ocorrencia2                        45331
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                     GUARULHOS
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       SBGR
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora                        13:44:00
# total_recomendacoes                           3
# Name: 1, dtype: object

# %%
data.iloc[1]
# Out:
# codigo_ocorrencia                         45331
# codigo_ocorrencia2                        45331
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                     GUARULHOS
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       SBGR
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora                        13:44:00
# total_recomendacoes                           3
# Name: 1, dtype: object

# %%
data.iloc[-1]
# Out:
# codigo_ocorrencia                         80467
# codigo_ocorrencia2                        80467
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                     PETROLINA
# ocorrencia_uf                                PE
# ocorrencia_aerodromo                       SBPL
# ocorrencia_dia              2021-12-31 00:00:00
# ocorrencia_hora                        20:30:00
# total_recomendacoes                           0
# Name: 5166, dtype: object

# %%
data.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5162             JATAÍ            GO                 <NA>     2021-12-30
# 5163           MARACAÍ            SP                 <NA>     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0

# %%
data.loc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              45332               45332                 ACIDENTE
# 11              52245               52245                INCIDENTE
# 12              45396               45396          INCIDENTE GRAVE
# 13              45408               45408                 ACIDENTE
# 14              45447               45447                INCIDENTE
# 15              45409               45409                 ACIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10            VIAMÃO            RS                 <NA>     2012-01-09
# 11      PORTO ALEGRE            RS                 SBPA     2012-01-09
# 12            MARABÁ            PA                 SBMA     2012-01-11
# 13          ELDORADO            SP                 <NA>     2012-01-11
# 14        RIO BRANCO            AC                 <NA>     2012-01-13
# 15           CÁCERES            MT                 <NA>     2012-01-14
#
#    ocorrencia_hora  total_recomendacoes
# 10        13:30:00                    0
# 11        13:36:00                    0
# 12        11:21:00                    0
# 13        13:45:00                    1
# 14        18:15:00                    0
# 15        10:00:00                    0

# %%
data.loc[:,'ocorrencia_uf']
# Out:
# 0       RS
# 1       SP
# 2       RS
# 3       SP
# 4       RS
#         ..
# 5162    GO
# 5163    SP
# 5164    RS
# 5165    PR
# 5166    PE
# Name: ocorrencia_uf, Length: 5167, dtype: object

# %%
data['ocorrencia_uf']
# Out:
# 0       RS
# 1       SP
# 2       RS
# 3       SP
# 4       RS
#         ..
# 5162    GO
# 5163    SP
# 5164    RS
# 5165    PR
# 5166    PE
# Name: ocorrencia_uf, Length: 5167, dtype: object

# %%
data.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
filtro = data.ocorrencia_uf.isnull()
data.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1099              49474               49474                 ACIDENTE
# 4728              79956               79956                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1099  ÁGUAS INTERNACIONAIS          <NA>                 <NA>     2013-09-02
# 4728      NÃO IDENTIFICADA          <NA>                 <NA>     2021-02-26
#
#      ocorrencia_hora  total_recomendacoes
# 1099        02:54:00                    0
# 4728        11:00:00                    0

# %%
filtro = data.ocorrencia_aerodromo.isnull()
data.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# 5                 52243               52243                INCIDENTE
# 8                 45391               45391                 ACIDENTE
# ...                 ...                 ...                      ...
# 5151              80446               80446                 ACIDENTE
# 5155              80450               80450                 ACIDENTE
# 5159              80455               80455          INCIDENTE GRAVE
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2                    VIAMÃO            RS                 <NA>     2012-01-06
# 3             SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4                  SÃO SEPÉ            RS                 <NA>     2012-01-06
# 5                   UBATUBA            SP                 <NA>     2012-01-06
# 8     CONCEIÇÃO DAS ALAGOAS            MG                 <NA>     2012-01-08
# ...                     ...           ...                  ...            ...
# 5151           JACAREACANGA            PA                 <NA>     2021-12-20
# 5155               DOURADOS            MS                 <NA>     2021-12-28
# 5159             SANTA RITA            PB                 <NA>     2021-12-29
# 5162                  JATAÍ            GO                 <NA>     2021-12-30
# 5163                MARACAÍ            SP                 <NA>     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 2           13:00:00                    0
# 3           17:00:00                    0
# 4           16:30:00                    0
# 5           14:30:00                    0
# 8           16:00:00                    0
# ...              ...                  ...
# 5151        17:10:00                    0
# 5155        10:30:00                    0
# 5159        18:50:00                    0
# 5162        20:30:00                    0
# 5163        09:30:00                    0
#
# [1905 rows x 9 columns]

# %%
filtro = data.ocorrencia_hora.isnull()
data.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2974              78823               78823                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2974           CORUMBÁ            MS                 <NA>     2017-07-09
#
#      ocorrencia_hora  total_recomendacoes
# 2974             NaN                    0

# %%
data.count()
# Out:
# codigo_ocorrencia           5167
# codigo_ocorrencia2          5167
# ocorrencia_classificacao    5167
# ocorrencia_cidade           5167
# ocorrencia_uf               5165
# ocorrencia_aerodromo        3262
# ocorrencia_dia              5167
# ocorrencia_hora             5166
# total_recomendacoes         5167
# dtype: int64

# %%
# ocorrências com mais de 10 recomendações
filtro = data.total_recomendacoes > 10
data.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 844               47938               47938                INCIDENTE
# 1669              52265               52265                 ACIDENTE
# 2804              66432               66432          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 844           BRASÍLIA            DF                 SBBR     2013-04-13
# 1669            SANTOS            SP                 <NA>     2014-08-13
# 2804           VITÓRIA            ES                 <NA>     2017-02-21
#
#      ocorrencia_hora  total_recomendacoes
# 844         18:00:00                   11
# 1669        13:03:00                   13
# 2804        11:47:00                   12

# %%
# ocorrências com mais de 10 recomendações
filtro = data.total_recomendacoes > 10
data.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#      ocorrencia_cidade  total_recomendacoes
# 844           BRASÍLIA                   11
# 1669            SANTOS                   13
# 2804           VITÓRIA                   12

# %%
# ocorrências cuja classificação == INCIDENTE GRAVE	
filtro = data.ocorrencia_classificacao == 'INCIDENTE GRAVE'
data.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 50713               50713          INCIDENTE GRAVE
# 12                45396               45396          INCIDENTE GRAVE
# 18                50714               50714          INCIDENTE GRAVE
# 19                45399               45399          INCIDENTE GRAVE
# 24                45582               45582          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5139              80427               80427          INCIDENTE GRAVE
# 5146              80448               80448          INCIDENTE GRAVE
# 5158              80454               80454          INCIDENTE GRAVE
# 5159              80455               80455          INCIDENTE GRAVE
# 5164              80457               80457          INCIDENTE GRAVE
#
#         ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6                CAMPINAS            SP                 SDAI     2012-01-07
# 12                 MARABÁ            PA                 SBMA     2012-01-11
# 18                CAMOCIM            CE                 SNWC     2012-01-17
# 19                  MUANÁ            PA                 <NA>     2012-01-18
# 24           RONDONÓPOLIS            MT                 SWRD     2012-01-20
# ...                   ...           ...                  ...            ...
# 5139    NOVA BANDEIRANTES            MT                 <NA>     2021-12-12
# 5146  FORMOSO DO ARAGUAIA            TO                 <NA>     2021-12-18
# 5158            ARAÇATUBA            SP                 SBAU     2021-12-29
# 5159           SANTA RITA            PB                 <NA>     2021-12-29
# 5164        NOVO HAMBURGO            RS                 SSNH     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 6           18:15:00                    0
# 12          11:21:00                    0
# 18          18:25:00                    0
# 19          17:35:00                    0
# 24          17:00:00                    0
# ...              ...                  ...
# 5139        17:20:00                    0
# 5146        19:00:00                    0
# 5158        21:35:00                    0
# 5159        18:50:00                    0
# 5164        11:59:00                    0
#
# [691 rows x 9 columns]

# %%
# ocorrências cuja classificação == INCIDENTE GRAVE e o estado == SP
filtro1 = data.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = data.ocorrencia_uf == 'SP'
data.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 50713               50713          INCIDENTE GRAVE
# 78                45598               45598          INCIDENTE GRAVE
# 86                45653               45653          INCIDENTE GRAVE
# 91                45599               45599          INCIDENTE GRAVE
# 140               45651               45651          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 4954              80200               80200          INCIDENTE GRAVE
# 4980              80238               80238          INCIDENTE GRAVE
# 5003              80265               80265          INCIDENTE GRAVE
# 5098              80382               80382          INCIDENTE GRAVE
# 5158              80454               80454          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6              CAMPINAS            SP                 SDAI     2012-01-07
# 78    BRAGANÇA PAULISTA            SP                 SBBP     2012-02-20
# 86            GUARULHOS            SP                 SBGR     2012-02-24
# 91    BRAGANÇA PAULISTA            SP                 SBBP     2012-02-27
# 140                 ITU            SP                 <NA>     2012-03-24
# ...                 ...           ...                  ...            ...
# 4954  BRAGANÇA PAULISTA            SP                 SDVH     2021-07-25
# 4980        VOTUPORANGA            SP                 SDVG     2021-08-11
# 5003          SÃO PAULO            SP                 SBMT     2021-08-31
# 5098         PIRACICABA            SP                 SDPW     2021-11-16
# 5158          ARAÇATUBA            SP                 SBAU     2021-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 6           18:15:00                    0
# 78          14:10:00                    0
# 86          20:04:00                    0
# 91          19:15:00                    0
# 140         20:45:00                    1
# ...              ...                  ...
# 4954        12:25:00                    0
# 4980        19:09:00                    0
# 5003        16:50:00                    0
# 5098        20:50:00                    0
# 5158        21:35:00                    0
#
# [132 rows x 9 columns]

# %%
# ocorrências cuja classificação == INCIDENTE GRAVE ou o estado == SP
filtro1 = data.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = data.ocorrencia_uf == 'SP'
data.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1                 45331               45331                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 5                 52243               52243                INCIDENTE
# 6                 50713               50713          INCIDENTE GRAVE
# 12                45396               45396          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5158              80454               80454          INCIDENTE GRAVE
# 5159              80455               80455          INCIDENTE GRAVE
# 5161              80456               80456                INCIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 3        SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 5              UBATUBA            SP                 <NA>     2012-01-06
# 6             CAMPINAS            SP                 SDAI     2012-01-07
# 12              MARABÁ            PA                 SBMA     2012-01-11
# ...                ...           ...                  ...            ...
# 5158         ARAÇATUBA            SP                 SBAU     2021-12-29
# 5159        SANTA RITA            PB                 <NA>     2021-12-29
# 5161         SÃO PAULO            SP                 SBSP     2021-12-30
# 5163           MARACAÍ            SP                 <NA>     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 1           13:44:00                    3
# 3           17:00:00                    0
# 5           14:30:00                    0
# 6           18:15:00                    0
# 12          11:21:00                    0
# ...              ...                  ...
# 5158        21:35:00                    0
# 5159        18:50:00                    0
# 5161        13:15:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
#
# [1820 rows x 9 columns]

# %%
# ocorrências cuja (classificação == INCIDENTE GRAVE ou classificação == INCIDENTE) e o estado == SP
filtro1 = data.ocorrencia_classificacao.isin(['INCIDENTE GRAVE', 'INCIDENTE'])
filtro2 = data.ocorrencia_uf == 'SP'
data.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 52243               52243                INCIDENTE
# 6                 50713               50713          INCIDENTE GRAVE
# 28                52248               52248                INCIDENTE
# 35                52054               52054                INCIDENTE
# 36                52055               52055                INCIDENTE
# ...                 ...                 ...                      ...
# 5134              80425               80425                INCIDENTE
# 5143              80431               80431                INCIDENTE
# 5157              80453               80453                INCIDENTE
# 5158              80454               80454          INCIDENTE GRAVE
# 5161              80456               80456                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5              UBATUBA            SP                 <NA>     2012-01-06
# 6             CAMPINAS            SP                 SDAI     2012-01-07
# 28           SÃO PAULO            SP                 SBMT     2012-01-21
# 35           SÃO PAULO            SP                 SBMT     2012-01-25
# 36      RIBEIRÃO PRETO            SP                 <NA>     2012-01-25
# ...                ...           ...                  ...            ...
# 5134         SÃO PAULO            SP                 SBSP     2021-12-09
# 5143            SANTOS            SP                 SBST     2021-12-15
# 5157          CAMPINAS            SP                 SBKP     2021-12-29
# 5158         ARAÇATUBA            SP                 SBAU     2021-12-29
# 5161         SÃO PAULO            SP                 SBSP     2021-12-30
#
#      ocorrencia_hora  total_recomendacoes
# 5           14:30:00                    0
# 6           18:15:00                    0
# 28          11:15:00                    0
# 35          23:00:00                    0
# 36          09:30:00                    0
# ...              ...                  ...
# 5134        20:30:00                    0
# 5143        12:30:00                    0
# 5157        09:00:00                    0
# 5158        21:35:00                    0
# 5161        13:15:00                    0
#
# [913 rows x 9 columns]

# %%
# ocorrências cuja cidade comecem com a letra C
filtro = data.ocorrencia_cidade.str[0] == 'C'
data.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 50713               50713          INCIDENTE GRAVE
# 8                 45391               45391                 ACIDENTE
# 15                45409               45409                 ACIDENTE
# 18                50714               50714          INCIDENTE GRAVE
# 22                45390               45390                 ACIDENTE
# ...                 ...                 ...                      ...
# 5142              80434               80434                 ACIDENTE
# 5144              80447               80447                INCIDENTE
# 5150              80445               80445                 ACIDENTE
# 5157              80453               80453                INCIDENTE
# 5165              80460               80460                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6                  CAMPINAS            SP                 SDAI     2012-01-07
# 8     CONCEIÇÃO DAS ALAGOAS            MG                 <NA>     2012-01-08
# 15                  CÁCERES            MT                 <NA>     2012-01-14
# 18                  CAMOCIM            CE                 SNWC     2012-01-17
# 22        CACHOEIRA DOURADA            GO                 <NA>     2012-01-20
# ...                     ...           ...                  ...            ...
# 5142                CARACOL            MS                 <NA>     2021-12-14
# 5144                CONFINS            MG                 SBCF     2021-12-15
# 5150            CHUPINGUAIA            RO                 <NA>     2021-12-20
# 5157               CAMPINAS            SP                 SBKP     2021-12-29
# 5165               CURITIBA            PR                 SBBI     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 6           18:15:00                    0
# 8           16:00:00                    0
# 15          10:00:00                    0
# 18          18:25:00                    0
# 22          21:00:00                    0
# ...              ...                  ...
# 5142        21:35:00                    0
# 5144        17:10:00                    0
# 5150        12:05:00                    0
# 5157        09:00:00                    0
# 5165        15:12:00                    0
#
# [771 rows x 9 columns]

# %%
# ocorrências cuja cidade terminam com a letra A
filtro = data.ocorrencia_cidade.str[-1] == 'A'
data.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 52243               52243                INCIDENTE
# 9                 52244               52244                INCIDENTE
# 17                52246               52246                INCIDENTE
# 21                45392               45392                 ACIDENTE
# 22                45390               45390                 ACIDENTE
# ...                 ...                 ...                      ...
# 5152              80465               80465                INCIDENTE
# 5158              80454               80454          INCIDENTE GRAVE
# 5159              80455               80455          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5               UBATUBA            SP                 <NA>     2012-01-06
# 9            UBERLÂNDIA            MG                 SBUL     2012-01-08
# 17             BRASÍLIA            DF                 SBBR     2012-01-16
# 21             BRASÍLIA            DF                 <NA>     2012-01-19
# 22    CACHOEIRA DOURADA            GO                 <NA>     2012-01-20
# ...                 ...           ...                  ...            ...
# 5152            VITÓRIA            ES                 SBVT     2021-12-21
# 5158          ARAÇATUBA            SP                 SBAU     2021-12-29
# 5159         SANTA RITA            PB                 <NA>     2021-12-29
# 5165           CURITIBA            PR                 SBBI     2021-12-31
# 5166          PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 5           14:30:00                    0
# 9           22:13:00                    0
# 17          16:47:00                    0
# 21          21:30:00                    2
# 22          21:00:00                    0
# ...              ...                  ...
# 5152        22:25:00                    0
# 5158        21:35:00                    0
# 5159        18:50:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0
#
# [1386 rows x 9 columns]

# %%
# ocorrências cuja cidade terminam com os caracteres MA
filtro = data.ocorrencia_cidade.str[-2:] == 'MA'
data.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 249               45939               45939                 ACIDENTE
# 273               46180               46180                 ACIDENTE
# 971               49113               49113          INCIDENTE GRAVE
# 974               48799               48799                 ACIDENTE
# 1518              80059               80059                INCIDENTE
# 1529              51347               51347                INCIDENTE
# 1729              52340               52340                 ACIDENTE
# 1840              52832               52832                 ACIDENTE
# 1871              52979               52979                 ACIDENTE
# 1914              52984               52984                 ACIDENTE
# 1966              53596               53596                INCIDENTE
# 2031              53223               53223                 ACIDENTE
# 2045              53265               53265                 ACIDENTE
# 2063              53271               53271          INCIDENTE GRAVE
# 2556              65414               65414          INCIDENTE GRAVE
# 2599              65633               65633          INCIDENTE GRAVE
# 2755              66265               66265                 ACIDENTE
# 3104              77371               77371                 ACIDENTE
# 3186              77612               77612                 ACIDENTE
# 3449              78080               78080                 ACIDENTE
# 3861              78867               78867                INCIDENTE
# 3945              78923               78923          INCIDENTE GRAVE
# 3955              78782               78782                 ACIDENTE
# 4279              79282               79282                 ACIDENTE
# 4314              79338               79338                INCIDENTE
# 4348              79400               79400                INCIDENTE
# 4632              79823               79823                 ACIDENTE
# 4649              79820               79820                INCIDENTE
# 4651              79830               79830                INCIDENTE
# 4734              79943               79943                INCIDENTE
# 4967              80227               80227                 ACIDENTE
# 4969              80252               80252                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 249           UMUARAMA            PR                 <NA>     2012-05-30
# 273          AURIFLAMA            SP                 <NA>     2012-06-16
# 971          NOVA LIMA            MG                 <NA>     2013-06-15
# 974           CANUTAMA            AM                 <NA>     2013-06-18
# 1518          IVINHEMA            MS                 <NA>     2014-04-27
# 1529           DIADEMA            SP                 <NA>     2014-05-04
# 1729              FAMA            MG                 <NA>     2014-09-20
# 1840          BURITAMA            SP                 <NA>     2014-12-14
# 1871          IVINHEMA            MS                 <NA>     2015-01-02
# 1914         NOVA LIMA            MG                 SJLY     2015-02-01
# 1966           ITAPEMA            SC                 <NA>     2015-03-10
# 2031         PINDORAMA            SP                 <NA>     2015-04-22
# 2045         PACARAIMA            RR                 SDMM     2015-05-05
# 2063          UMUARAMA            PR                 <NA>     2015-05-17
# 2556         NOVA LIMA            MG                 SJLY     2016-07-08
# 2599         NOVA LIMA            MG                 <NA>     2016-08-31
# 2755          BURITAMA            SP                 <NA>     2017-01-13
# 3104          CANUTAMA            AM                 SDKH     2017-11-02
# 3186           ITAPEMA            SC                 <NA>     2018-01-06
# 3449           ITAPEMA            SC                 <NA>     2018-07-28
# 3861           IRACEMA            RR                 <NA>     2019-07-06
# 3945          CANUTAMA            AM                 <NA>     2019-09-03
# 3955          IVINHEMA            MS                 <NA>     2019-09-08
# 4279           ITURAMA            MG                 <NA>     2020-04-11
# 4314          IVINHEMA            MS                 <NA>     2020-05-15
# 4348           IBIRAMA            SC                 <NA>     2020-06-09
# 4632           IRACEMA            RR                 <NA>     2021-01-05
# 4649         NOVA LIMA            MG                 SJLY     2021-01-14
# 4651         NOVA LIMA            MG                 SJLY     2021-01-14
# 4734         IBOTIRAMA            BA                 SNIT     2021-03-03
# 4967          UMUARAMA            PR                 <NA>     2021-08-02
# 4969           IRACEMA            RR                 <NA>     2021-08-04
#
#      ocorrencia_hora  total_recomendacoes
# 249         19:00:00                    0
# 273         19:30:00                    0
# 971         12:00:00                    4
# 974         21:30:00                    0
# 1518        11:30:00                    0
# 1529        16:00:00                    0
# 1729        15:00:00                    1
# 1840        23:40:00                    0
# 1871        14:50:00                    0
# 1914        15:10:00                    0
# 1966        21:35:00                    0
# 2031        12:45:00                    0
# 2045        16:05:00                    2
# 2063        17:00:00                    0
# 2556        19:50:00                    1
# 2599        17:40:00                    0
# 2755        16:00:00                    0
# 3104        19:30:00                    1
# 3186        10:30:00                    0
# 3449        14:20:00                    0
# 3861        00:00:00                    0
# 3945        14:00:00                    0
# 3955        17:45:00                    0
# 4279        12:20:00                    0
# 4314        09:40:00                    0
# 4348        14:00:00                    0
# 4632        20:07:00                    0
# 4649        09:27:00                    0
# 4651        09:27:00                    0
# 4734        11:30:00                    0
# 4967        14:30:00                    0
# 4969        11:45:00                    0

# %%
# ocorrências cuja cidade contém (em qualquer parte do conteúdo) os caracteres MA ou AL
filtro = data.ocorrencia_cidade.str.contains('MA|AL')
data.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 8                 45391               45391                 ACIDENTE
# 11                52245               52245                INCIDENTE
# 12                45396               45396          INCIDENTE GRAVE
# 16                45693               45693                INCIDENTE
# ...                 ...                 ...                      ...
# 5153              80461               80461                INCIDENTE
# 5154              80468               80468                INCIDENTE
# 5156              80463               80463                INCIDENTE
# 5160              80451               80451                INCIDENTE
# 5163              80452               80452                 ACIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0              PORTO ALEGRE            RS                 SBPA     2012-01-05
# 8     CONCEIÇÃO DAS ALAGOAS            MG                 <NA>     2012-01-08
# 11             PORTO ALEGRE            RS                 SBPA     2012-01-09
# 12                   MARABÁ            PA                 SBMA     2012-01-11
# 16                    MACAÉ            RJ                 <NA>     2012-01-14
# ...                     ...           ...                  ...            ...
# 5153                MARINGÁ            PR                 SBMG     2021-12-24
# 5154               SALVADOR            BA                 SBSV     2021-12-26
# 5156                MARINGÁ            PR                 SBMG     2021-12-28
# 5160                 MANAUS            AM                 SBEG     2021-12-30
# 5163                MARACAÍ            SP                 <NA>     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 8           16:00:00                    0
# 11          13:36:00                    0
# 12          11:21:00                    0
# 16          10:30:00                    0
# ...              ...                  ...
# 5153        03:30:00                    0
# 5154        16:56:00                    0
# 5156        16:11:00                    0
# 5160        14:41:00                    0
# 5163        09:30:00                    0
#
# [791 rows x 9 columns]

# %%
# ocorrências do ano de 2015
filtro = data.ocorrencia_dia.dt.year == 2015
data.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1870              52992               52992          INCIDENTE GRAVE
# 1871              52979               52979                 ACIDENTE
# 1872              53073               53073                INCIDENTE
# 1873              53074               53074                INCIDENTE
# 1874              52976               52976                 ACIDENTE
# ...                 ...                 ...                      ...
# 2336              60632               60632          INCIDENTE GRAVE
# 2337              60600               60600                INCIDENTE
# 2338              60642               60642                INCIDENTE
# 2339              60631               60631                 ACIDENTE
# 2340              60649               60649                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1870              SALVADOR            BA                 SBSV     2015-01-01
# 1871              IVINHEMA            MS                 <NA>     2015-01-02
# 1872                  TEFÉ            AM                 SBTF     2015-01-02
# 1873        BELO HORIZONTE            MG                 SBBH     2015-01-02
# 1874                TOLEDO            PR                 SBTD     2015-01-04
# ...                    ...           ...                  ...            ...
# 2336               ITABERÁ            SP                 <NA>     2015-12-24
# 2337             GUARULHOS            SP                 SBGR     2015-12-25
# 2338  SÃO FRANCISCO DO SUL            SC                 SSSS     2015-12-26
# 2339             MAÇAMBARÁ            RS                 <NA>     2015-12-28
# 2340            PORTO BELO            SC                 SDEN     2015-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 1870        11:40:00                    3
# 1871        14:50:00                    0
# 1872        16:28:00                    0
# 1873        20:34:00                    0
# 1874        22:04:00                    6
# ...              ...                  ...
# 2336        14:00:00                    0
# 2337        19:00:00                    0
# 2338        16:00:00                    0
# 2339        19:00:00                    2
# 2340        14:00:00                    0
#
# [471 rows x 9 columns]

# %%
data.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
#ocorrências do ano de 2015 e mês 12 e dias entre 3 e 8
filtro_ano = data.ocorrencia_dia.dt.year == 2015
filtro_mes = data.ocorrencia_dia.dt.month == 12
filtro_dia_inicio = data.ocorrencia_dia.dt.day > 2 
filtro_dia_fim = data.ocorrencia_dia.dt.day < 9
data.loc[filtro_ano & filtro_mes & filtro_dia_inicio & filtro_dia_fim]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2306              53575               53575                INCIDENTE
# 2307              60637               60637                INCIDENTE
# 2308              53625               53625                 ACIDENTE
# 2309              53626               53626                 ACIDENTE
# 2310              53628               53628                 ACIDENTE
# 2311              53629               53629          INCIDENTE GRAVE
# 2312              53631               53631                INCIDENTE
# 2313              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2306  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 2307         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 2308               TRINDADE            GO                 <NA>     2015-12-06
# 2309              AMERICANA            SP                 SDAI     2015-12-06
# 2310                  AGUAÍ            SP                 <NA>     2015-12-08
# 2311                  JALES            SP                 SDJL     2015-12-08
# 2312               CAMPINAS            SP                 SBKP     2015-12-08
# 2313          CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 2306        10:50:00                    0
# 2307        16:47:00                    0
# 2308        13:10:00                    3
# 2309        15:00:00                    1
# 2310        14:30:00                    1
# 2311        10:20:00                    0
# 2312        16:19:00                    0
# 2313        13:00:00                    0

# %%
data['ocorrencia_dia_hora'] = pd.to_datetime(data.ocorrencia_dia.astype(str) + ' '  + data.ocorrencia_hora)

# %%
data.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 <NA>     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4          SÃO SEPÉ            RS                 <NA>     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0        20:27:00                    0 2012-01-05 20:27:00
# 1        13:44:00                    3 2012-01-06 13:44:00
# 2        13:00:00                    0 2012-01-06 13:00:00
# 3        17:00:00                    0 2012-01-06 17:00:00
# 4        16:30:00                    0 2012-01-06 16:30:00

# %%
filtro1 = data.ocorrencia_dia_hora >= '2015-12-03 11:00:00'
filtro2 = data.ocorrencia_dia_hora <= '2015-12-08 14:30:00'
data.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2307              60637               60637                INCIDENTE
# 2308              53625               53625                 ACIDENTE
# 2309              53626               53626                 ACIDENTE
# 2310              53628               53628                 ACIDENTE
# 2311              53629               53629          INCIDENTE GRAVE
# 2313              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2307    BELO HORIZONTE            MG                 SBBH     2015-12-03
# 2308          TRINDADE            GO                 <NA>     2015-12-06
# 2309         AMERICANA            SP                 SDAI     2015-12-06
# 2310             AGUAÍ            SP                 <NA>     2015-12-08
# 2311             JALES            SP                 SDJL     2015-12-08
# 2313     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 2307        16:47:00                    0 2015-12-03 16:47:00
# 2308        13:10:00                    3 2015-12-06 13:10:00
# 2309        15:00:00                    1 2015-12-06 15:00:00
# 2310        14:30:00                    1 2015-12-08 14:30:00
# 2311        10:20:00                    0 2015-12-08 10:20:00
# 2313        13:00:00                    0 2015-12-08 13:00:00

# %%
# ocorrências do ano de 2015 e mês 03
filtro1 = data.ocorrencia_dia.dt.year == 2015
filtro2 = data.ocorrencia_dia.dt.month == 3
df201503 = data.loc[filtro1 & filtro2]
df201503
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1960              53183               53183                 ACIDENTE
# 1961              53120               53120                 ACIDENTE
# 1962              53109               53109                 ACIDENTE
# 1963              53112               53112                 ACIDENTE
# 1964              53152               53152          INCIDENTE GRAVE
# 1965              53167               53167                INCIDENTE
# 1966              53596               53596                INCIDENTE
# 1967              53149               53149                 ACIDENTE
# 1968              53148               53148                 ACIDENTE
# 1969              53153               53153                INCIDENTE
# 1970              53154               53154                INCIDENTE
# 1971              53238               53238                INCIDENTE
# 1972              53189               53189                INCIDENTE
# 1973              53193               53193                 ACIDENTE
# 1974              53164               53164                 ACIDENTE
# 1975              53151               53151          INCIDENTE GRAVE
# 1976              53168               53168                INCIDENTE
# 1977              53169               53169                INCIDENTE
# 1978              53165               53165          INCIDENTE GRAVE
# 1979              53188               53188                INCIDENTE
# 1980              53184               53184                 ACIDENTE
# 1981              53178               53178                 ACIDENTE
# 1982              53182               53182                 ACIDENTE
# 1983              53166               53166          INCIDENTE GRAVE
# 1984              53170               53170                INCIDENTE
# 1985              53185               53185                INCIDENTE
# 1986              53412               53412          INCIDENTE GRAVE
# 1987              53194               53194                 ACIDENTE
# 1988              53186               53186                INCIDENTE
# 1989              53179               53179                 ACIDENTE
# 1990              53180               53180                 ACIDENTE
# 1991              53190               53190                INCIDENTE
# 1992              53212               53212                INCIDENTE
# 1993              53213               53213                INCIDENTE
# 1994              53181               53181                 ACIDENTE
# 1995              53187               53187                INCIDENTE
# 1996              53211               53211                INCIDENTE
#
#         ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1960              AMAPORÃ            PR                 <NA>     2015-03-02
# 1961               CHAVES            PA                 SNXW     2015-03-04
# 1962         CAMPO GRANDE            MS                 SSIE     2015-03-05
# 1963           MOGI GUAÇU            SP                 <NA>     2015-03-06
# 1964       RIO DE JANEIRO            RJ                 SBRJ     2015-03-10
# 1965               MARABÁ            PA                 SBMA     2015-03-10
# 1966              ITAPEMA            SC                 <NA>     2015-03-10
# 1967            TABATINGA            AM                 SBTT     2015-03-11
# 1968               ARARAS            SP                 SDEH     2015-03-12
# 1969         PORTO ALEGRE            RS                 SBPA     2015-03-13
# 1970             SOROCABA            SP                 SDCO     2015-03-13
# 1971                SERRA            ES                 <NA>     2015-03-13
# 1972              CONFINS            MG                 SBCF     2015-03-14
# 1973             CANARANA            MT                 <NA>     2015-03-14
# 1974      PRINCESA ISABEL            PB                 <NA>     2015-03-15
# 1975                MAUÉS            AM                 SWMW     2015-03-16
# 1976        PARÁ DE MINAS            MG                 SNPA     2015-03-16
# 1977                BELÉM            PA                 SBBE     2015-03-19
# 1978        SÃO DESIDÉRIO            BA                 <NA>     2015-03-20
# 1979       RIO DE JANEIRO            RJ                 SBJR     2015-03-20
# 1980          PORTO UNIÃO            SC                 <NA>     2015-03-22
# 1981           DIAMANTINO            MT                 <NA>     2015-03-23
# 1982          SANTA LUZIA            MA                 <NA>     2015-03-23
# 1983    RIACHÃO DAS NEVES            BA                 <NA>     2015-03-24
# 1984              CONFINS            MG                 SBCF     2015-03-24
# 1985             CURITIBA            PR                 SBCT     2015-03-24
# 1986                MACAÉ            RJ                 <NA>     2015-03-24
# 1987  GUARACIABA DO NORTE            CE                 SWBE     2015-03-26
# 1988             BRASÍLIA            DF                 <NA>     2015-03-27
# 1989            CAIAPÔNIA            GO                 <NA>     2015-03-28
# 1990             ARAGUARI            MG                 <NA>     2015-03-28
# 1991             CAMPINAS            SP                 SBKP     2015-03-28
# 1992              JUNDIAÍ            SP                 SBJD     2015-03-28
# 1993              JUNDIAÍ            SP                 SBJD     2015-03-28
# 1994              COLÍDER            MT                 <NA>     2015-03-29
# 1995            JOINVILLE            SC                 SBJV     2015-03-29
# 1996                BAURU            SP                 SBBU     2015-03-30
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 1960        23:00:00                    0 2015-03-02 23:00:00
# 1961        13:30:00                    0 2015-03-04 13:30:00
# 1962        13:50:00                    0 2015-03-05 13:50:00
# 1963        21:00:00                    1 2015-03-06 21:00:00
# 1964        11:30:00                    2 2015-03-10 11:30:00
# 1965        17:33:00                    0 2015-03-10 17:33:00
# 1966        21:35:00                    0 2015-03-10 21:35:00
# 1967        23:25:00                    0 2015-03-11 23:25:00
# 1968        12:40:00                    0 2015-03-12 12:40:00
# 1969        15:45:00                    0 2015-03-13 15:45:00
# 1970        14:40:00                    0 2015-03-13 14:40:00
# 1971        11:30:00                    0 2015-03-13 11:30:00
# 1972        07:20:00                    0 2015-03-14 07:20:00
# 1973        18:00:00                    0 2015-03-14 18:00:00
# 1974        18:30:00                    0 2015-03-15 18:30:00
# 1975        18:07:00                    1 2015-03-16 18:07:00
# 1976        21:05:00                    0 2015-03-16 21:05:00
# 1977        03:25:00                    0 2015-03-19 03:25:00
# 1978        14:35:00                    0 2015-03-20 14:35:00
# 1979        21:00:00                    0 2015-03-20 21:00:00
# 1980        13:44:00                    0 2015-03-22 13:44:00
# 1981        17:15:00                    0 2015-03-23 17:15:00
# 1982        20:40:00                    0 2015-03-23 20:40:00
# 1983        14:45:00                    0 2015-03-24 14:45:00
# 1984        17:57:00                    0 2015-03-24 17:57:00
# 1985        23:01:00                    0 2015-03-24 23:01:00
# 1986        16:35:00                    0 2015-03-24 16:35:00
# 1987        20:30:00                    0 2015-03-26 20:30:00
# 1988        14:55:00                    0 2015-03-27 14:55:00
# 1989        10:30:00                    0 2015-03-28 10:30:00
# 1990        18:52:00                    0 2015-03-28 18:52:00
# 1991        16:26:00                    0 2015-03-28 16:26:00
# 1992        17:32:00                    0 2015-03-28 17:32:00
# 1993        15:51:00                    0 2015-03-28 15:51:00
# 1994        20:17:00                    0 2015-03-29 20:17:00
# 1995        18:36:00                    0 2015-03-29 18:36:00
# 1996        19:40:00                    0 2015-03-30 19:40:00

# %%
df201503.count()
# Out:
# codigo_ocorrencia           37
# codigo_ocorrencia2          37
# ocorrencia_classificacao    37
# ocorrencia_cidade           37
# ocorrencia_uf               37
# ocorrencia_aerodromo        21
# ocorrencia_dia              37
# ocorrencia_hora             37
# total_recomendacoes         37
# ocorrencia_dia_hora         37
# dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).codigo_ocorrencia.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# Name: codigo_ocorrencia, dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).ocorrencia_aerodromo.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE            5
# INCIDENTE          14
# INCIDENTE GRAVE     2
# Name: ocorrencia_aerodromo, dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).size().sort_values()
# Out:
# ocorrencia_classificacao
# INCIDENTE GRAVE     5
# ACIDENTE           15
# INCIDENTE          17
# dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=False)
# Out:
# ocorrencia_classificacao
# INCIDENTE          17
# ACIDENTE           15
# INCIDENTE GRAVE     5
# dtype: int64

# %%
filtro1 = data.ocorrencia_dia.dt.year == 2012
filtro2 = data.ocorrencia_uf.isin(['PR','SC','RS'])
dfsul2012 = data.loc[filtro1 & filtro2]
dfsul2012
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                52242               52242                INCIDENTE
# 2                45333               45333                 ACIDENTE
# 4                45407               45407                 ACIDENTE
# 10               45332               45332                 ACIDENTE
# 11               52245               52245                INCIDENTE
# ..                 ...                 ...                      ...
# 607              46752               46752                 ACIDENTE
# 609              46789               46789                INCIDENTE
# 615              46751               46751                 ACIDENTE
# 621              46823               46823          INCIDENTE GRAVE
# 635              46792               46792                INCIDENTE
#
#            ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0               PORTO ALEGRE            RS                 SBPA
# 2                     VIAMÃO            RS                 <NA>
# 4                   SÃO SEPÉ            RS                 <NA>
# 10                    VIAMÃO            RS                 <NA>
# 11              PORTO ALEGRE            RS                 SBPA
# ..                       ...           ...                  ...
# 607  SANTA VITÓRIA DO PALMAR            RS                 <NA>
# 609             PORTO ALEGRE            RS                 SBPA
# 615               URUGUAIANA            RS                 SJDU
# 621           ROSÁRIO DO SUL            RS                 SSRZ
# 635             PORTO ALEGRE            RS                 SBPA
#
#     ocorrencia_dia ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0       2012-01-05        20:27:00                    0 2012-01-05 20:27:00
# 2       2012-01-06        13:00:00                    0 2012-01-06 13:00:00
# 4       2012-01-06        16:30:00                    0 2012-01-06 16:30:00
# 10      2012-01-09        13:30:00                    0 2012-01-09 13:30:00
# 11      2012-01-09        13:36:00                    0 2012-01-09 13:36:00
# ..             ...             ...                  ...                 ...
# 607     2012-12-10        10:30:00                    1 2012-12-10 10:30:00
# 609     2012-12-10        19:45:00                    0 2012-12-10 19:45:00
# 615     2012-12-13        22:00:00                    2 2012-12-13 22:00:00
# 621     2012-12-16        22:30:00                    1 2012-12-16 22:30:00
# 635     2012-12-26        21:40:00                    0 2012-12-26 21:40:00
#
# [93 rows x 10 columns]

# %%
dfsul2012.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           34
# INCIDENTE          44
# INCIDENTE GRAVE    15
# dtype: int64

# %%
dfsul2012.count()
# Out:
# codigo_ocorrencia           93
# codigo_ocorrencia2          93
# ocorrencia_classificacao    93
# ocorrencia_cidade           93
# ocorrencia_uf               93
# ocorrencia_aerodromo        59
# ocorrencia_dia              93
# ocorrencia_hora             93
# total_recomendacoes         93
# ocorrencia_dia_hora         93
# dtype: int64

# %%
dfsul2012.groupby(['ocorrencia_uf', 'ocorrencia_classificacao']).size()
# Out:
# ocorrencia_uf  ocorrencia_classificacao
# PR             ACIDENTE                    14
#                INCIDENTE                   23
#                INCIDENTE GRAVE              6
# RS             ACIDENTE                    13
#                INCIDENTE                   18
#                INCIDENTE GRAVE              6
# SC             ACIDENTE                     7
#                INCIDENTE                    3
#                INCIDENTE GRAVE              3
# dtype: int64

# %%
dfsul2012.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# PORTO ALEGRE               14
# LONDRINA                   12
# CURITIBA                    9
# CASCAVEL                    4
# MARINGÁ                     3
# PELOTAS                     3
# VIAMÃO                      2
# NAVEGANTES                  2
# LUIZ ALVES                  2
# FOZ DO IGUAÇU               2
# SANTA MARIA                 2
# OSÓRIO                      2
# SÃO JOSÉ                    2
# SÃO JOSÉ DOS PINHAIS        2
# SÃO SEPÉ                    2
# SANTA VITÓRIA DO PALMAR     1
# SANTO ÂNGELO                1
# SÃO BORJA                   1
# ROSÁRIO DO SUL              1
# RIO GRANDE                  1
# QUERÊNCIA DO NORTE          1
# TOLEDO                      1
# PONTA GROSSA                1
# UMUARAMA                    1
# URUGUAIANA                  1
# SANTA MARIANA               1
# ALEGRETE                    1
# PALMEIRA                    1
# ALMIRANTE TAMANDARÉ         1
# ALTÔNIA                     1
# ARROIO GRANDE               1
# BAGÉ                        1
# BALNEÁRIO CAMBORIÚ          1
# BELA VISTA DO PARAÍSO       1
# BLUMENAU                    1
# CAMPINA GRANDE DO SUL       1
# CHAPECÓ                     1
# CORUPÁ                      1
# ESPUMOSO                    1
# FLORIANÓPOLIS               1
# GUAÍBA                      1
# IMBITUBA                    1
# ITAQUI                      1
# JOINVILLE                   1
# MARECHAL CÂNDIDO RONDON     1
# dtype: int64

# %%
filtro1 = dfsul2012.ocorrencia_cidade == 'URUGUAIANA'
filtro2 = dfsul2012.total_recomendacoes > 0
dfsul2012.loc[filtro1 & filtro2]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 615              46751               46751                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 615        URUGUAIANA            RS                 SJDU     2012-12-13
#
#     ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 615        22:00:00                    2 2012-12-13 22:00:00

# %%
filtro = dfsul2012.ocorrencia_cidade == 'URUGUAIANA'
dfsul2012.loc[filtro].total_recomendacoes.sum()
# Out:
# 2

# %%
dfsul2012.groupby(['ocorrencia_aerodromo'], dropna=False).total_recomendacoes.sum()
# Out:
# ocorrencia_aerodromo
# SBBI     0
# SBCA     1
# SBCT     0
# SBFI     0
# SBFL     0
# SBJV     0
# SBLO     0
# SBMG     0
# SBNF     0
# SBNM     0
# SBPA     0
# SBPG     0
# SBPK     0
# SBTD     0
# SIBK     1
# SJDU     2
# SSBL     0
# SSBN     0
# SSCR     2
# SSHS     2
# SSKT     0
# SSOK     0
# SSOS     0
# SSRZ     1
# SSSB     0
# SSXO     0
# NaN     14
# Name: total_recomendacoes, dtype: int64

# %%
dfsul2012.groupby(['ocorrencia_cidade']).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade
# ALEGRETE                   0
# ALMIRANTE TAMANDARÉ        9
# ALTÔNIA                    0
# ARROIO GRANDE              0
# BAGÉ                       1
# BALNEÁRIO CAMBORIÚ         0
# BELA VISTA DO PARAÍSO      0
# BLUMENAU                   0
# CAMPINA GRANDE DO SUL      0
# CASCAVEL                   1
# CHAPECÓ                    0
# CORUPÁ                     0
# CURITIBA                   0
# ESPUMOSO                   0
# FLORIANÓPOLIS              0
# FOZ DO IGUAÇU              2
# GUAÍBA                     0
# IMBITUBA                   0
# ITAQUI                     0
# JOINVILLE                  0
# LONDRINA                   0
# LUIZ ALVES                 1
# MARECHAL CÂNDIDO RONDON    2
# MARINGÁ                    0
# NAVEGANTES                 0
# OSÓRIO                     0
# PALMEIRA                   3
# PELOTAS                    0
# PONTA GROSSA               0
# PORTO ALEGRE               0
# QUERÊNCIA DO NORTE         0
# RIO GRANDE                 0
# ROSÁRIO DO SUL             1
# SANTA MARIA                0
# SANTA MARIANA              0
# SANTA VITÓRIA DO PALMAR    1
# SANTO ÂNGELO               0
# SÃO BORJA                  0
# SÃO JOSÉ                   0
# SÃO JOSÉ DOS PINHAIS       0
# SÃO SEPÉ                   0
# TOLEDO                     0
# UMUARAMA                   0
# URUGUAIANA                 2
# VIAMÃO                     0
# Name: total_recomendacoes, dtype: int64

# %%
filtro = dfsul2012.total_recomendacoes > 0
dfsul2012.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values()
# Out:
# ocorrencia_cidade
# BAGÉ                       1
# CASCAVEL                   1
# LUIZ ALVES                 1
# ROSÁRIO DO SUL             1
# SANTA VITÓRIA DO PALMAR    1
# FOZ DO IGUAÇU              2
# MARECHAL CÂNDIDO RONDON    2
# URUGUAIANA                 2
# PALMEIRA                   3
# ALMIRANTE TAMANDARÉ        9
# Name: total_recomendacoes, dtype: int64

# %%
dfsul2012.loc[filtro].groupby(['ocorrencia_cidade', dfsul2012.ocorrencia_dia.dt.month]).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade        ocorrencia_dia
# ALMIRANTE TAMANDARÉ      11                9
# BAGÉ                     11                1
# CASCAVEL                 9                 1
# FOZ DO IGUAÇU            9                 2
# LUIZ ALVES               3                 1
# MARECHAL CÂNDIDO RONDON  5                 2
# PALMEIRA                 8                 3
# ROSÁRIO DO SUL           12                1
# SANTA VITÓRIA DO PALMAR  12                1
# URUGUAIANA               12                2
# Name: total_recomendacoes, dtype: int64

# %%
filtro1 = dfsul2012.total_recomendacoes > 0
filtro2 = dfsul2012.ocorrencia_cidade == 'ROSÁRIO DO SUL'
dfsul2012.loc[filtro1 & filtro2]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 621              46823               46823          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 621    ROSÁRIO DO SUL            RS                 SSRZ     2012-12-16
#
#     ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 621        22:30:00                    1 2012-12-16 22:30:00
